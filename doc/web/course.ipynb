# %% [markdown]
# <!-- Strange way of testing for vortex... -->
# <!-- dom:TITLE: Overview of course material: PHY981 Nuclear Structure  -->
# # Overview of course material: PHY981 Nuclear Structure
# <!-- dom:AUTHOR: Morten Hjorth-Jensen Email:hjensen@nscl.msu.edu -->
# <!-- Author: --> **Morten Hjorth-Jensen** (email: `hjensen@nscl.msu.edu`)
#
#
#
#
#
#
#
#
#
#
#
# The teaching material is produced in various formats for printing and on-screen reading.
#
# The PDF files are based on LaTeX and have seldom technical
# failures that cannot be easily corrected.
# The HTML-based files, called "HTML" and "ipynb" below, apply MathJax
# for rendering LaTeX formulas and sometimes this technology gives rise
# to unexpected failures (e.g.,
# incorrect rendering in a web page despite correct LaTeX syntax in the
# formula). Consult the corresponding PDF
# files if you find missing or incorrectly rendered
# formulas in HTML or ipython notebook files.
#
#
# # PHY 981: Nuclear Structure notes
#
# ## Introduction to nuclear structure
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/intro/pdf/intro-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/intro/pdf/intro-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/intro/pdf/intro-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/intro/html/intro.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/intro/html/intro-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/intro/html/intro-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/intro/ipynb/intro.ipynb)
#
#
# ## Single-particle data, experimental information and simple models
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/spdata/pdf/spdata-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/spdata/pdf/spdata-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/spdata/pdf/spdata-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/spdata/html/spdata.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/spdata/html/spdata-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/spdata/html/spdata-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/spdata/ipynb/spdata.ipynb)
#
#
# ## Mean-field theories
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/hfock/pdf/hfock-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/hfock/pdf/hfock-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/hfock/pdf/hfock-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/hfock/html/hfock.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/hfock/html/hfock-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/hfock/html/hfock-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/hfock/ipynb/hfock.ipynb)
#
#
# ## Second quantization
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/secondquant/pdf/secondquant-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/secondquant/pdf/secondquant-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/secondquant/pdf/secondquant-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/secondquant/html/secondquant.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/secondquant/html/secondquant-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/secondquant/html/secondquant-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/secondquant/ipynb/secondquant.ipynb)
#
#
# ## Models for nuclear forces
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/forces/pdf/forces-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/forces/pdf/forces-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/forces/pdf/forces-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/forces/html/forces.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/forces/html/forces-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/forces/html/forces-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/forces/ipynb/forces.ipynb)
#
#
# ## The nuclear shell model and full configuration interaction theory
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/fci/pdf/fci-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/fci/pdf/fci-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/fci/pdf/fci-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/fci/html/fci.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/fci/html/fci-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/fci/html/fci-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/fci/ipynb/fci.ipynb)
#
#
# ## Nuclear decays
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/decays/pdf/decays-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/decays/pdf/decays-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/decays/pdf/decays-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/decays/html/decays.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/decays/html/decays-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/decays/html/decays-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/decays/ipynb/decays.ipynb)
#
#
# ## Pairing, random-phase approximation and simple models
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/simplemodels/pdf/simplemodels-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/simplemodels/pdf/simplemodels-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/simplemodels/pdf/simplemodels-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/simplemodels/html/simplemodels.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/simplemodels/html/simplemodels-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/simplemodels/html/simplemodels-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/simplemodels/ipynb/simplemodels.ipynb)
#
#
# ## Effective interactions for the nuclear shell-model
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/mbpt/pdf/mbpt-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/mbpt/pdf/mbpt-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/mbpt/pdf/mbpt-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/mbpt/html/mbpt.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/mbpt/html/mbpt-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/mbpt/html/mbpt-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/mbpt/ipynb/mbpt.ipynb)
#
#
# ## Coupled cluster theory and nuclear structure
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/cc/pdf/cc-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/cc/pdf/cc-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/cc/pdf/cc-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/cc/html/cc.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/cc/html/cc-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/cc/html/cc-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/cc/ipynb/cc.ipynb)
#
#
# ## Similarity transformation methods
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/srg/pdf/srg-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/srg/pdf/srg-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/srg/pdf/srg-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/srg/html/srg.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/srg/html/srg-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/srg/html/srg-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/srg/ipynb/srg.ipynb)
#
#
# ## Green function theory based methods
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/gf/pdf/gf-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/gf/pdf/gf-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/gf/pdf/gf-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/gf/html/gf.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/gf/html/gf-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/gf/html/gf-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/gf/ipynb/gf.ipynb)
#
#
# ## Monte Carlo  methods
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/mc/pdf/mc-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/mc/pdf/mc-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/mc/pdf/mc-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/mc/html/mc.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/mc/html/mc-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/mc/html/mc-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/mc/ipynb/mc.ipynb)
#
#
# ## From nuclei to stars, properties of infinite nuclear matter, symmetric and neutron rich
#
#
#
#  * LaTeX PDF:
#
#    * For printing:
#
#      * [Standard one-page format](http://nuclearstructure.github.io/PHY981/doc/pub/inf/pdf/inf-print.pdf), compact: [6 pages per sheet](http://nuclearstructure.github.io/PHY981/doc/pub/inf/pdf/inf-print6.pdf)
#
#
#    * For screen viewing:
#
#      * [standard Beamer format](http://nuclearstructure.github.io/PHY981/doc/pub/inf/pdf/inf-beamer.pdf)
#
#
#
#  * HTML:
#
#    * [Plain html style](http://nuclearstructure.github.io/PHY981/doc/pub/inf/html/inf.html)
#
#    * [Reveal html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/inf/html/inf-reveal.html)
#
#    * [Bootstrap html style for easy reading on mobile devices](http://nuclearstructure.github.io/PHY981/doc/pub/inf/html/inf-bs.html)
#
#
#  * iPython notebook:
#
#    * [ipynb file](http://nuclearstructure.github.io/PHY981/doc/pub/inf/ipynb/inf.ipynb)
#
#
# ## Schedule Spring 2016
#
# All lectures are in the main conference room of the theory trailer.
#
#
# <table border="1">
# <thead>
# <tr><th align="center">       Week and days       </th> <th align="center">                Topics to be covered                </th> <th align="center">                                                 Exercises and projects                                                </th> <th align="center">                                     Reading assignments                                      </th> <th align="center">           Additional activities            </th> </tr>
# </thead>
# <tbody>
# <tr><td align="center">   Week 2 January 11-15           </td> <td align="center">   Introduction                                            </td> <td align="center">   [Exercise set 1](https://github.com/NuclearStructure/PHY981/tree/master/doc/ProjectsExercises/exercises/2016/Exercise1)    </td> <td align="center">   [Chapters 1-4 of Brown](https://github.com/NuclearStructure/PHY981/tree/master/doc/literature)    </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Observables, masses, radii and definitions              </td> <td align="center">                                                                                                                              </td> <td align="center">   [Lecture notes](http://nuclearstructure.github.io/PHY981/doc/pub/spdata/html/spdata-bs.html)      </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 3 January 18-22           </td> <td align="center">   Single particle properties                              </td> <td align="center">   [Exercise 1](https://github.com/NuclearStructure/PHY981/tree/master/doc/ProjectsExercises/exercises/2016/Exercise1)        </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Definitions, basis sets and begin Hartree-Fock          </td> <td align="center">                                                                                                                              </td> <td align="center">   [Lecture notes](http://nuclearstructure.github.io/PHY981/doc/pub/hfock/html/hfock-bs.html)        </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 4 January 25-29           </td> <td align="center">   Hartree-Fock                                            </td> <td align="center">   [Exercise set 2](https://github.com/NuclearStructure/PHY981/tree/master/doc/ProjectsExercises/exercises/2016/Exercise2)    </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Single-particle quantum numbers, second quantization    </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 5 February 1-5            </td> <td align="center">   Second quantization                                     </td> <td align="center">   [Exercise set 3](https://github.com/NuclearStructure/PHY981/tree/master/doc/ProjectsExercises/exercises/2016/Exercise3)    </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Hartree-Fock final                                      </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 6 February 8-12           </td> <td align="center">   Second quantization                                     </td> <td align="center">   [Project 1](https://github.com/NuclearStructure/PHY981/tree/master/doc/ProjectsExercises/projects/2016/Project1)           </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">                                                           </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 7 February 15-19          </td> <td align="center">   Nuclear forces                                          </td> <td align="center">   Work on project 1                                                                                                          </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">                                                           </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 8 February 22-26          </td> <td align="center">   Nuclear forces                                          </td> <td align="center">   Work on project 1                                                                                                          </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">                                                           </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 9 February 29 -March 4    </td> <td align="center">   Nuclear shell model                                     </td> <td align="center">   Work on project 1                                                                                                          </td> <td align="center">                                                                                                     </td> <td align="center">   Deadline for project 1 is March 4               </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">                                                           </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 10 March 7-11             </td> <td align="center">   Spring break                                            </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 11 March 14-18            </td> <td align="center">   Nuclear shell model                                     </td> <td align="center">   [Exercise set 4](https://github.com/NuclearStructure/PHY981/tree/master/doc/ProjectsExercises/exercises/2016/Exercise4)    </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Effective Hamiltonians                                  </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 12 March 21-25            </td> <td align="center">   Nuclear shell model                                     </td> <td align="center">   [Exercise set 5](https://github.com/NuclearStructure/PHY981/tree/master/doc/ProjectsExercises/exercises/2016/Exercise5)    </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Effective Hamiltonians and operators                    </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 13 March 28 -April 1      </td> <td align="center">   Effective Hamiltonians and operators                    </td> <td align="center">   [Project 2](https://github.com/NuclearStructure/PHY981/tree/master/doc/ProjectsExercises/projects/2016/Project2)           </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Nuclear decays                                          </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 14 April 4-8              </td> <td align="center">   Nuclear decays                                          </td> <td align="center">   Work on project 2                                                                                                          </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Electromagnetic decays                                  </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 15 April 11-15            </td> <td align="center">   Nuclear decays                                          </td> <td align="center">   Work on project 2                                                                                                          </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Electromagnetic and Electroweak decays                  </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 16 April 18-22            </td> <td align="center">   Nuclear decays                                          </td> <td align="center">   Work on project 2                                                                                                          </td> <td align="center">                                                                                                     </td> <td align="center">   Deadline for project 2 April 18                 </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Electroweak decays                                      </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">   Presentation of projects for final oral exam    </td> </tr>
# <tr><td align="center">   Week 17 April 25-29            </td> <td align="center">   Nuclear decays                                          </td> <td align="center">   Work on final oral exam project                                                                                            </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">                                  </td> <td align="center">   Summary of course                                       </td> <td align="center">                                                                                                                              </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# <tr><td align="center">   Week 18  May 2-6               </td> <td align="center">   Finals week                                             </td> <td align="center">   Time and schedule TBA                                                                                                      </td> <td align="center">                                                                                                     </td> <td align="center">                                                   </td> </tr>
# </tbody>
# </table>
#
#
# ## Basic Syllabus
# * Syllabus: Lecture notes, exercises and projects. Relevant chapters of Suhonen's text that cover parts of the material are chapters 3-9 and 11. Chapters 1-2 on angular momentum will be used as references for various derivations and only parts of these two chapters will be used. Alex Brown's lecture notes from 2011 can also be used, and the relevant chapters are 1-4, 6-29. Chapter 5 of Brown on angular momentum plays the same role as chapters 1-2 of Suhonen.
#
# ## Main themes and reading suggestions
# The various observables we will discuss in the course are thought to be understood via the following five major topics
# * Single  particle properties and mean-field models, lecture notes, Suhonen chapters 3-5 and Brown chapters 7-10 and 14
#
# * Nuclear forces, covered by lecture notes
#
# * The nuclear shell-model, lecture notes, Suhonen chapter 8 and Brown chapters 11-22.
#
# * Decays and one and two-body transition probabilities, lecture notes, Suhonen chapters 6 and 7, Brown chapters 23-29.
#
# * If time allows, Particle-hole excitations, random-phase approximation and pairing (and perhaps something on collective models), lecture notes and Suhonen chapters 9 and 11.
#
# ## Links to all course material
# * PHY981 on github
#
#  * All material is at  <https://github.com/NuclearStructure/PHY981/>
#
#  * The link <http://nuclearstructure.github.io/PHY981/doc/web/course.html> gives direct access to html, ipython notebooks and pdf files of the lectures.
#
#
# ## Projects, exercises and final oral exam
# **Projects, weekly exercises, deadlines and final oral exam.**
#
# * Two  projects with a possible numerical content that count 25% each of the final mark, weekly exercises  that count 20% and a final oral exam which counts 30% of the final grade.
#
# * Project 1 will be available in week 6 (begins with February 8) and to be handed in before spring break (March 4)
#
# * Project 2 will be available in week 13 (begins with March 28) with deadline April 18.
#
# * For the final oral exam you have to prepare a 25-30 minutes talk based on either a topic chosen by you or a topic defined towards the end of the semester.
#
# Duration of the examination is 45 minutes.
#
#
#
#
# ## Selected Texts on Nuclear Structure and Many-body theory
# * Nuclear structure
#
#  * Heyde, *The Nuclear Shell Model*, Springer 1990
#
#  * Lawson, *Theory of the Nuclear Shell Model*, Oxford 1980
#
#  * Ring and Schuck, *Nuclear Many-Body Theory*, Springer 1980
#
#  * Talmi, *Simple Models of Complex Nuclei: The Shell Model and Interacting Boson Model*, Harwood Academic Publishers 1993.
#
#
# * Many-body theories
#
#  * Blaizot and Ripka, *Quantum Theory of Finite systems*, MIT press 1986
#
#  * Fetter and Walecka, *Quantum Theory of Many-Particle Systems*, McGraw-Hill, 1971.
#
#  * Dickhoff and Van Neck, *Many-Body Theory Exposed*, World Scientific, 2006.
#
#
#
# ## Links and useful software
# * Useful links
#
#  * When I write code in C++ I tend to recommend to use the linear algebra library [armadillo](http://arma.sourceforge.net/).
#
#  * For OS X users I recommend using [brew](http://brew.sh/).
#
#  * To set up github, use the [guides](https://guides.github.com/) and/or the github [link](https://github.com/).
#
#  * An excellent IDE for c++ programmers is [Qt Creator](http://www.qt.io/ide/)
